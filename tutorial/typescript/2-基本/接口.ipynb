// %%
interface User {
  id: number;
  name: string;
  phone: string;
}

// %%
const user: User = {
  id: 1,
  name: '张乔巧',
  phone: '15611111111',
};

user;
// Out:
// { id: 1, name: '张乔巧', phone: '15611111111' }

// %%
interface IUserService {
  getById(id: number);
  
  delete(id: number);
}

// %%
class UserService implements IUserService {
  public getById(id: number) {
      
  }
    
  public delete(id: number) {
      
  }
}

// %%
const userService: IUserService = new UserService();

userService;
// Out:
// UserService {}

// %% [markdown]
// 通过 `interface` 扩展函数和字段：

// %%
class User {
  id: number;
  firstName: string;
  lastName: string;
}

interface User {
  phone: string;
  getFullName(): string;
}

User.prototype.getFullName = function() {
  return this.firstName + this.lastName;  
};

const user = new User();

user.id = 1;
user.firstName = '李';
user.lastName = '泽星'
user.phone = '15611111111';

user.getFullName();
// Out:
// 李泽星
